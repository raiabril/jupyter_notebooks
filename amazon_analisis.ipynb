# %%
PATH = '/Volumes/Home Directory-1/logs'

# %%
# %matplotlib inline
import pandas as pd
import os
os.chdir(PATH)
import matplotlib.pyplot as plt

data = pd.read_csv('amazon_logs.csv',delimiter=',',encoding='utf-8',parse_dates=['DATE'])
data['BRAND']= data.PRODUCT.str.split()
data['BRAND'] = data.BRAND.apply(lambda x: x[0])

# %%
#data.hist()

# %%
pivot = data.pivot_table(columns='ASIN', index=[data.DATE.dt.month,data.DATE.dt.day], values='PRICE')
pivot.plot()
pivot.head()
# Out:
# /Users/raimundoabrillopez/anaconda/lib/python3.5/site-packages/matplotlib/axes/_base.py:2917: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=0.0, right=0.0
#   'left=%s, right=%s') % (left, right))
# ASIN       B005MNGQ6C  B0093RMTY6  B00CRZ2PRM  B00D0L5BH8  B00K4V9QW8  \
# DATE DATE
# 8    11          69.0      107.25        57.9        86.8       10.99
#
# ASIN       B00KWHJT7Q  B00KWHJVCY  B00KWHJY7Q  B00TKFEEAS  B00WIMBNGI  \
# DATE DATE
# 8    11         44.95       73.62        52.9        59.9       102.8
#
# ASIN       B012PN8UZQ  B01AJWNWWQ  B01AJWNXAM  B01AJWNYLA  B01D9KX8KG  \
# DATE DATE
# 8    11        173.59      123.12       73.32        49.9        9.99
#
# ASIN       B01LQQH86A  B01LYKIZXN  B01N9SN9ST  B06VVS7S94  B071YSP7JQ
# DATE DATE
# 8    11         145.0       24.02      154.51       57.85       52.59

# %%
pivot.describe()
# Out:
# ASIN   B005MNGQ6C  B0093RMTY6  B00CRZ2PRM  B00D0L5BH8  B00K4V9QW8  B00KWHJT7Q  \
# count         1.0        1.00         1.0         1.0        1.00        1.00
# mean         69.0      107.25        57.9        86.8       10.99       44.95
# std           NaN         NaN         NaN         NaN         NaN         NaN
# min          69.0      107.25        57.9        86.8       10.99       44.95
# 25%          69.0      107.25        57.9        86.8       10.99       44.95
# 50%          69.0      107.25        57.9        86.8       10.99       44.95
# 75%          69.0      107.25        57.9        86.8       10.99       44.95
# max          69.0      107.25        57.9        86.8       10.99       44.95
#
# ASIN   B00KWHJVCY  B00KWHJY7Q  B00TKFEEAS  B00WIMBNGI  B012PN8UZQ  B01AJWNWWQ  \
# count        1.00         1.0         1.0         1.0        1.00        1.00
# mean        73.62        52.9        59.9       102.8      173.59      123.12
# ...
